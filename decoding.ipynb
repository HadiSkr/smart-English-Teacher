# %%
#C:\\Users\\Hadi\\Documents\\recorded_audio.wav

import sounddevice as sd
import soundfile as sf
import librosa
import numpy as np

aligned_frames = []
corpus_frames = []
frame_duration = 0.02

# Set up audio parameters
sample_rate = 22050  # Sample rate in Hz
duration = 1  # Duration of recording in seconds

# Start recording
print("Recording started...")
recorded_audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
sd.wait()  # Wait until recording is finished

# Save recorded audio to file
audio_file = 'C:\\Users\\Hadi\\Documents\\recorded_audio.wav'
sf.write(audio_file, recorded_audio, sample_rate)

# Load audio file using librosa


audio, sr = librosa.load(audio_file)
mfccs = librosa.feature.mfcc(y=audio, sr=sr, hop_length=int(frame_duration * sr))

frames = mfccs[:, :]
aligned_frames.append(frames)
corpus_frames.extend(aligned_frames)
"""
scaling_factor = 2.8


# Calculate the average length of the aligned frames
average_length = int(np.mean([len(frames[0]) for frames in corpus_frames]) * scaling_factor)

# Truncate longer sequences and pad shorter sequences
truncated_aligned_frames = []
for frames in corpus_frames:
    if len(frames[0]) > average_length:
        truncated_frames = frames[:, :average_length]
    else:
        padding = np.zeros((frames.shape[0], average_length - len(frames[0])))
        truncated_frames = np.concatenate((frames, padding), axis=1)
    truncated_aligned_frames.append(truncated_frames)

# Convert the list to a NumPy array
"""
corpus_frames = np.array(corpus_frames)

reshaped_frames = np.transpose(corpus_frames, (2, 1, 0))
reshaped_frames = np.tile(reshaped_frames, (1, 1, 8))
reshaped_frames = reshaped_frames.reshape(reshaped_frames.shape[0], reshaped_frames.shape[1], -1)

print("Shape of reshaped_frames:", reshaped_frames.shape)

corpus_frames = np.reshape(reshaped_frames, (reshaped_frames.shape[0], 20, 8, 1))
# Normalize the data
mean = np.mean(corpus_frames)
std = np.std(corpus_frames)
# Check if the standard deviation is zero
if std == 0:
    std = 1e-7  # add a small epsilon value to prevent division by zero

aligned_frames_normalized = (corpus_frames - mean) / std
print(aligned_frames_normalized.shape)

model = tf.keras.models.load_model("C:\\Users\\Hadi\\Documents\\phoneme_model.h5") 

predicted_labels = model.predict(aligned_frames_normalized)
# Convert predicted phoneme indices to phoneme labels
phoneme_dict = {
    0: 'er',
    1: 'aa',
    2: 'ahn',
    3: 'ah',
    4: 'tq',
    5: 'nx',
    6: 'jh',
    7: 'own',
    8: 'ihn',
    9: 'hh',
    10: 'ey',
    11: 'v',
    12: 'l',
    13: 'dh',
    14: 'uh',
    15: 'f',
    16: 'r',
    17: 'uw',
    18: 'aen',
    19: 's',
    20: 'ao',
    21: 'b',
    22: 't',
    23: 'ih',
    24: 'th',
    25: 'oy',
    26: 'SIL',
    27: 'ch',
    28: 'eng',
    29: 'eh',
    30: 'p',
    31: 'sh',
    32: 'ehn',
    33: 'ay',
    34: 'z',
    35: 'w',
    36: 'g',
    37: 'm',
    38: 'aw',
    39: 'em',
    40: 'el',
    41: 'ae',
    42: 'd',
    43: 'k',
    44: 'dx',
    45: 'en',
    46: 'y',
    47: 'ow',
    48: 'ng',
    49: 'iy',
    50: 'zh',
    51: 'n'
}



predicted_phonemes = []
for row in predicted_labels:
    predicted_index = np.argmax(row)
    predicted_phoneme = phoneme_dict[predicted_index]
    predicted_phonemes.append(predicted_phoneme)

phoneme0 = '-'
print("Predicted Phonemes:")
for phoneme in predicted_phonemes:
    if  phoneme!=phoneme0:
       phoneme0 = phoneme
       print(phoneme)
# Print the pre
# dicted phoneme labels


# Now you can use the loaded audio data (audio) and sample rate (sr)
# for further processing or analysis
# Out:
# Recording started...
# Shape of reshaped_frames: (51, 20, 8)
# (51, 20, 8, 1)
# WARNING:tensorflow:6 out of the last 16 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002390F7D5280> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 9ms/step
# Predicted Phonemes:
# SIL
# m
# ah
# eh
# hh
# m
# dh
# r
# eh
# ae
# r
# s
# z
# n
# f
# s
# f
# SIL
# ey
# ae
# ah

# %%
# Out:
# c:\Users\Hadi\anaconda3\envs\tf2\lib\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 30
#      28 num_frames = mfccs.shape[1]
#      29 padding_width = (20 - (num_frames % 20)) % 20  # Calculate padding width to make MFCC frames divisible by 20
# ---> 30 mfccs = np.pad(mfccs, [(0, 0), (0, padding_width), (0, 0)], mode='constant')  # Apply padding to ensure divisibility by 20
#      31 mfccs = mfccs.reshape(-1, 20, 8, 1)  # Reshape to match the expected input shape
#      37 predictions = model.predict(mfccs)  # Feed the model with the preprocessed audio
#
# File <__array_function__ internals>:200, in pad(*args, **kwargs)
#
# ...

# %%
# Out:
# 1/1 [==============================] - 4s 4s/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 26
#      24     predictions = model.predict(frame)
#      25     predicted_index = np.argmax(predictions)
# ---> 26     predicted_phoneme = phoneme_mapping[predicted_index]
#      27     predicted_phonemes.append(predicted_phoneme)
#      29 print("Predicted Phonemes:", predicted_phonemes)
#
# NameError: name 'phoneme_mapping' is not defined

# %%
# Out:
# Shape of reshaped_frames: (87236, 20, 8)
# (87236, 20, 8, 1)
# 2727/2727 [==============================] - 6s 2ms/step
# Predicted Phonemes:
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# em
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# ...

# %%
# Out:
# Recording started...
# Shape of reshaped_frames: (201, 20, 8)
# (201, 20, 8, 1)
# 7/7 [==============================] - 0s 10ms/step
# Predicted Phonemes:
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# n
# m
# m
# ow
# ow
# ah
# ah
# em
# en
# ng
# iy
# ih
# hh
# hh
# ey
# hh
# hh
# ae
# r
# r
# r
# ae
# ae
# ae
# ae
# r
# r
# ae
# r
# r
# r
# ah
# ae
# ah
# ah
# th
# SIL
# ae
# hh
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ah
# ae
# ae
# ah
# ah
# r
# ah
# ah
# m
# ah
# ah
# ah
# SIL
# SIL
# em
# em
# em
# em
# m
# m
# SIL
# em
# em
# em
# em
# ah
# ae
# em
# em
# em
# m
# m
# m
# em
# m
# m
# m
# em
# m
# hh
# m
# f
# f
# th
# f
# SIL
# n
# th
# SIL
# SIL
# s
# SIL
# SIL
# n
# em
# m
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# SIL
# ...
